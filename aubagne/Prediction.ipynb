# %% [markdown]
# # Prediction des distances

# %% [markdown]
# ## Importation des packages necessaires

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import numpy as np
import seaborn as sns
import time
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## Creation du Frame

# %%
import glob
import os

all_files = glob.glob("aubagne_propre.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))

# %% [markdown]
# ## Affichage de l'entete du frame

# %%
df
# Out:
#                              date   DistX   DistY  T_Amb_h  T_Fc_h     Vbat
# 0       2018-10-10 22:28:00+00:00  1481.0  4068.0   18.435  16.870  12967.5
# 1       2018-10-10 22:40:00+00:00  1481.0  4068.0   18.370  16.870  12961.0
# 2       2018-10-10 22:52:00+00:00  1481.0  4068.0   18.430  16.870  12957.0
# 3       2018-10-10 23:04:00+00:00  1481.0  4068.0   18.370  16.870  12954.0
# 4       2018-10-10 23:16:00+00:00  1481.0  4068.0   18.370  16.810  12952.0
# ...                           ...     ...     ...      ...     ...      ...
# 166046  2023-02-10 18:52:00+00:00  1514.0  3795.0    2.560   4.930  12867.0
# 166047  2023-02-10 19:04:00+00:00  1514.0  3794.0    2.030   4.375  12856.0
# 166048  2023-02-10 19:16:00+00:00  1514.0  3792.0    1.500   3.810  12845.0
# 166049  2023-02-10 19:28:00+00:00  1515.0  3791.0    1.120   3.370  12837.0
# 166050  2023-02-10 19:40:00+00:00  1515.0  3788.0    1.250   3.310  12830.0
#
# [166051 rows x 6 columns]

# %% [markdown]
# ## Renommer les colonnes

# %%
df = df.rename({"DistX":"distx", "DistY":"disty",},axis=1)

# %% [markdown]
# ## Definir la colonne index

# %%
df = df.set_index("date")
df.head()
# Out:
#                             distx   disty  T_Amb_h  T_Fc_h     Vbat
# date
# 2018-10-10 22:28:00+00:00  1481.0  4068.0   18.435   16.87  12967.5
# 2018-10-10 22:40:00+00:00  1481.0  4068.0   18.370   16.87  12961.0
# 2018-10-10 22:52:00+00:00  1481.0  4068.0   18.430   16.87  12957.0
# 2018-10-10 23:04:00+00:00  1481.0  4068.0   18.370   16.87  12954.0
# 2018-10-10 23:16:00+00:00  1481.0  4068.0   18.370   16.81  12952.0

# %% [markdown]
# ## Mettre la date (l'index) sous un format exploitable

# %%
df.index = pd.to_datetime(df.index, format="mixed")
df.head()
# Out:
#                             distx   disty  T_Amb_h  T_Fc_h     Vbat
# date
# 2018-10-10 22:28:00+00:00  1481.0  4068.0   18.435   16.87  12967.5
# 2018-10-10 22:40:00+00:00  1481.0  4068.0   18.370   16.87  12961.0
# 2018-10-10 22:52:00+00:00  1481.0  4068.0   18.430   16.87  12957.0
# 2018-10-10 23:04:00+00:00  1481.0  4068.0   18.370   16.87  12954.0
# 2018-10-10 23:16:00+00:00  1481.0  4068.0   18.370   16.81  12952.0

# %% [markdown]
# ## Classer le frame par date croissante

# %%
df.sort_values(by=['date'], inplace=True)
df.head()
# Out:
#                             distx   disty  T_Amb_h  T_Fc_h     Vbat
# date
# 2018-10-10 22:28:00+00:00  1481.0  4068.0   18.435   16.87  12967.5
# 2018-10-10 22:40:00+00:00  1481.0  4068.0   18.370   16.87  12961.0
# 2018-10-10 22:52:00+00:00  1481.0  4068.0   18.430   16.87  12957.0
# 2018-10-10 23:04:00+00:00  1481.0  4068.0   18.370   16.87  12954.0
# 2018-10-10 23:16:00+00:00  1481.0  4068.0   18.370   16.81  12952.0

# %% [markdown]
# ## Afficher le frame

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(18, 16))

df['distx'].plot(ax=axes[0])
axes[0].set_title('Graphique de distx')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Valeurs de distx')

df['disty'].plot(ax=axes[1])
axes[1].set_title('Graphique de disty')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Valeurs de disty')

df['T_Amb_h'].plot(ax=axes[2])
axes[2].set_title('Graphique de T_Amb_h')
axes[2].set_xlabel('Index')
axes[2].set_ylabel('Valeurs de T_Amb_h')

df['T_Fc_h'].plot(ax=axes[3])
axes[3].set_title('Graphique de T_Fc_h')
axes[3].set_xlabel('Index')
axes[3].set_ylabel('Valeurs de T_Fc_h')

df['Vbat'].plot(ax=axes[4])
axes[4].set_title('Graphique de Vbat')
axes[4].set_xlabel('Index')
axes[4].set_ylabel('Valeurs de Vbat')

plt.tight_layout()
plt.show()

# %%
start_date = '2021-07-01'
end_date = '2022-01-31'

df_filtered = df.loc[start_date:end_date]

fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(18, 16))

df_filtered['distx'].plot(ax=axes[0])
axes[0].set_title('Graphique de distx')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Valeurs de distx')

df_filtered['disty'].plot(ax=axes[1])
axes[1].set_title('Graphique de disty')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Valeurs de disty')

df_filtered['T_Amb_h'].plot(ax=axes[2])
axes[2].set_title('Graphique de T_Amb_h')
axes[2].set_xlabel('Index')
axes[2].set_ylabel('Valeurs de T_Amb_h')

df_filtered['T_Fc_h'].plot(ax=axes[3])
axes[3].set_title('Graphique de T_Fc_h')
axes[3].set_xlabel('Index')
axes[3].set_ylabel('Valeurs de T_Fc_h')

df_filtered['Vbat'].plot(ax=axes[4])
axes[4].set_title('Graphique de Vbat')
axes[4].set_xlabel('Index')
axes[4].set_ylabel('Valeurs de Vbat')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Afficher les donnees sous certaines conditions

# %%
df[(df.index > "2020-01-01") & (df.index < "2021-01-01")]
# Out:
#                             distx   disty  T_Amb_h  T_Fc_h     Vbat
# date
# 2020-01-01 00:04:00+00:00  1521.0  3867.0     2.50   1.560  12934.0
# 2020-01-01 00:16:00+00:00  1521.0  3867.0     2.31   1.405  12931.0
# 2020-01-01 00:28:00+00:00  1521.0  3867.0     2.37   1.430  12929.0
# 2020-01-01 00:40:00+00:00  1521.0  3867.0     2.31   1.370  12928.0
# 2020-01-01 00:52:00+00:00  1522.0  3866.0     2.18   1.120  12926.0
# ...                           ...     ...      ...     ...      ...
# 2020-12-31 23:04:00+00:00  1519.0  3865.0     5.06   5.750  12833.0
# 2020-12-31 23:16:00+00:00  1519.0  3865.0     5.06   5.810  12830.0
# 2020-12-31 23:28:00+00:00  1520.0  3865.0     5.18   5.930  12828.0
# 2020-12-31 23:40:00+00:00  1519.0  3865.0     5.25   6.000  12825.0
# 2020-12-31 23:52:00+00:00  1519.0  3865.0     5.28   6.000  12822.0
#
# [38692 rows x 5 columns]

# %% [markdown]
# ## Creation des Features

# %%
from vacances_scolaires_france import SchoolHolidayDates
from jours_feries_france import JoursFeries
from datetime import date
import holidays

# %%
def set_features(df):
    # Copie du dataframe original pour éviter de le modifier directement
    df = df.copy()
    
    # Ajout des caractéristiques temporelles
    df["minuteofhour"] = df.index.minute  # Minute de l'heure
    df['minuteofday'] = df.index.hour * 60 + df.index.minute  # Minute du jour
    df['minuteofmonth'] = df.index.day * 24 * 60 + df['minuteofday']  # Minute du mois
    df['minuteofyear'] = df.index.dayofyear * 24 * 60 + df['minuteofday']  # Minute de l'année
    df["hourofday"] = df.index.hour  # Heure de la journée
    df['hourofmonth'] = df.index.day * 24 + df['hourofday']  # Heure du mois
    df['hourofyear'] = df.index.dayofyear * 24 + df['hourofday']  # Heure de l'année
    df['dayofweek'] = df.index.dayofweek  # Jour de la semaine (lundi=0, dimanche=6)
    df["dayofmonth"] = df.index.day  # Jour du mois
    df["dayofyear"] = df.index.dayofyear  # Jour de l'année
    df['weekofmonth'] = (df['dayofmonth'] - 1) // 7 + 1  # Semaine du mois
    df['weekofyear'] = df.index.isocalendar().week
    df['month'] = df.index.month  # Mois de l'année
    df['quarter'] = df.index.quarter  # Trimestre de l'année
    df["year"] = df.index.year  # Année
    return df

# %%
df = set_features(df)
df
# Out:
#                             distx   disty  T_Amb_h  T_Fc_h     Vbat  \
# date
# 2018-10-10 22:28:00+00:00  1481.0  4068.0   18.435  16.870  12967.5
# 2018-10-10 22:40:00+00:00  1481.0  4068.0   18.370  16.870  12961.0
# 2018-10-10 22:52:00+00:00  1481.0  4068.0   18.430  16.870  12957.0
# 2018-10-10 23:04:00+00:00  1481.0  4068.0   18.370  16.870  12954.0
# 2018-10-10 23:16:00+00:00  1481.0  4068.0   18.370  16.810  12952.0
# ...                           ...     ...      ...     ...      ...
# 2023-02-10 18:52:00+00:00  1514.0  3795.0    2.560   4.930  12867.0
# 2023-02-10 19:04:00+00:00  1514.0  3794.0    2.030   4.375  12856.0
# 2023-02-10 19:16:00+00:00  1514.0  3792.0    1.500   3.810  12845.0
# 2023-02-10 19:28:00+00:00  1515.0  3791.0    1.120   3.370  12837.0
# 2023-02-10 19:40:00+00:00  1515.0  3788.0    1.250   3.310  12830.0
#
#                            minuteofhour  minuteofday  minuteofmonth  \
# date
# 2018-10-10 22:28:00+00:00            28         1348          15748
# 2018-10-10 22:40:00+00:00            40         1360          15760
# 2018-10-10 22:52:00+00:00            52         1372          15772
# 2018-10-10 23:04:00+00:00             4         1384          15784
# 2018-10-10 23:16:00+00:00            16         1396          15796
# ...                                 ...          ...            ...
# 2023-02-10 18:52:00+00:00            52         1132          15532
# 2023-02-10 19:04:00+00:00             4         1144          15544
# 2023-02-10 19:16:00+00:00            16         1156          15556
# 2023-02-10 19:28:00+00:00            28         1168          15568
# 2023-02-10 19:40:00+00:00            40         1180          15580
#
#                            minuteofyear  hourofday  hourofmonth  hourofyear  \
# date
# 2018-10-10 22:28:00+00:00        408868         22          262        6814
# 2018-10-10 22:40:00+00:00        408880         22          262        6814
# 2018-10-10 22:52:00+00:00        408892         22          262        6814
# 2018-10-10 23:04:00+00:00        408904         23          263        6815
# 2018-10-10 23:16:00+00:00        408916         23          263        6815
# ...                                 ...        ...          ...         ...
# 2023-02-10 18:52:00+00:00         60172         18          258        1002
# 2023-02-10 19:04:00+00:00         60184         19          259        1003
# 2023-02-10 19:16:00+00:00         60196         19          259        1003
# 2023-02-10 19:28:00+00:00         60208         19          259        1003
# 2023-02-10 19:40:00+00:00         60220         19          259        1003
#
#                            dayofweek  dayofmonth  dayofyear  weekofmonth  \
# date
# 2018-10-10 22:28:00+00:00          2          10        283            2
# 2018-10-10 22:40:00+00:00          2          10        283            2
# 2018-10-10 22:52:00+00:00          2          10        283            2
# 2018-10-10 23:04:00+00:00          2          10        283            2
# 2018-10-10 23:16:00+00:00          2          10        283            2
# ...                              ...         ...        ...          ...
# 2023-02-10 18:52:00+00:00          4          10         41            2
# 2023-02-10 19:04:00+00:00          4          10         41            2
# 2023-02-10 19:16:00+00:00          4          10         41            2
# 2023-02-10 19:28:00+00:00          4          10         41            2
# 2023-02-10 19:40:00+00:00          4          10         41            2
#
#                            weekofyear  month  quarter  year
# date
# 2018-10-10 22:28:00+00:00          41     10        4  2018
# 2018-10-10 22:40:00+00:00          41     10        4  2018
# 2018-10-10 22:52:00+00:00          41     10        4  2018
# 2018-10-10 23:04:00+00:00          41     10        4  2018
# 2018-10-10 23:16:00+00:00          41     10        4  2018
# ...                               ...    ...      ...   ...
# 2023-02-10 18:52:00+00:00           6      2        1  2023
# 2023-02-10 19:04:00+00:00           6      2        1  2023
# 2023-02-10 19:16:00+00:00           6      2        1  2023
# 2023-02-10 19:28:00+00:00           6      2        1  2023
# 2023-02-10 19:40:00+00:00           6      2        1  2023
#
# [166051 rows x 20 columns]

# %%
def set_holidays(df, country, state, start_year, end_year):
    # Copie du dataframe original pour éviter de le modifier directement
    df = df.copy()
    
    # Création d'un dictionnaire contenant les dates des jours fériés
    list_holidays = holidays.CountryHoliday(country, state=state, years=range(start_year, end_year+1))
    
    # Ajout d'une colonne pour les jours fériés
    df['holidays'] = df.index.to_series().apply(lambda x: 1 if x in list_holidays else 0)
    
    return df

# %%
df = set_holidays(df, "FRA", "Métropole", 2018, 2023)
df
# Out:
#                             distx   disty  T_Amb_h  T_Fc_h     Vbat  \
# date
# 2018-10-10 22:28:00+00:00  1481.0  4068.0   18.435  16.870  12967.5
# 2018-10-10 22:40:00+00:00  1481.0  4068.0   18.370  16.870  12961.0
# 2018-10-10 22:52:00+00:00  1481.0  4068.0   18.430  16.870  12957.0
# 2018-10-10 23:04:00+00:00  1481.0  4068.0   18.370  16.870  12954.0
# 2018-10-10 23:16:00+00:00  1481.0  4068.0   18.370  16.810  12952.0
# ...                           ...     ...      ...     ...      ...
# 2023-02-10 18:52:00+00:00  1514.0  3795.0    2.560   4.930  12867.0
# 2023-02-10 19:04:00+00:00  1514.0  3794.0    2.030   4.375  12856.0
# 2023-02-10 19:16:00+00:00  1514.0  3792.0    1.500   3.810  12845.0
# 2023-02-10 19:28:00+00:00  1515.0  3791.0    1.120   3.370  12837.0
# 2023-02-10 19:40:00+00:00  1515.0  3788.0    1.250   3.310  12830.0
#
#                            minuteofhour  minuteofday  minuteofmonth  \
# date
# 2018-10-10 22:28:00+00:00            28         1348          15748
# 2018-10-10 22:40:00+00:00            40         1360          15760
# 2018-10-10 22:52:00+00:00            52         1372          15772
# 2018-10-10 23:04:00+00:00             4         1384          15784
# 2018-10-10 23:16:00+00:00            16         1396          15796
# ...                                 ...          ...            ...
# 2023-02-10 18:52:00+00:00            52         1132          15532
# 2023-02-10 19:04:00+00:00             4         1144          15544
# 2023-02-10 19:16:00+00:00            16         1156          15556
# 2023-02-10 19:28:00+00:00            28         1168          15568
# 2023-02-10 19:40:00+00:00            40         1180          15580
#
#                            minuteofyear  hourofday  ...  hourofyear  \
# date                                                ...
# 2018-10-10 22:28:00+00:00        408868         22  ...        6814
# 2018-10-10 22:40:00+00:00        408880         22  ...        6814
# 2018-10-10 22:52:00+00:00        408892         22  ...        6814
# 2018-10-10 23:04:00+00:00        408904         23  ...        6815
# 2018-10-10 23:16:00+00:00        408916         23  ...        6815
# ...                                 ...        ...  ...         ...
# 2023-02-10 18:52:00+00:00         60172         18  ...        1002
# 2023-02-10 19:04:00+00:00         60184         19  ...        1003
# 2023-02-10 19:16:00+00:00         60196         19  ...        1003
# 2023-02-10 19:28:00+00:00         60208         19  ...        1003
# 2023-02-10 19:40:00+00:00         60220         19  ...        1003
#
#                            dayofweek  dayofmonth  dayofyear  weekofmonth  \
# date
# 2018-10-10 22:28:00+00:00          2          10        283            2
# 2018-10-10 22:40:00+00:00          2          10        283            2
# 2018-10-10 22:52:00+00:00          2          10        283            2
# 2018-10-10 23:04:00+00:00          2          10        283            2
# 2018-10-10 23:16:00+00:00          2          10        283            2
# ...                              ...         ...        ...          ...
# 2023-02-10 18:52:00+00:00          4          10         41            2
# 2023-02-10 19:04:00+00:00          4          10         41            2
# 2023-02-10 19:16:00+00:00          4          10         41            2
# 2023-02-10 19:28:00+00:00          4          10         41            2
# 2023-02-10 19:40:00+00:00          4          10         41            2
#
#                            weekofyear  month  quarter  year  holidays
# date
# 2018-10-10 22:28:00+00:00          41     10        4  2018         0
# 2018-10-10 22:40:00+00:00          41     10        4  2018         0
# 2018-10-10 22:52:00+00:00          41     10        4  2018         0
# 2018-10-10 23:04:00+00:00          41     10        4  2018         0
# 2018-10-10 23:16:00+00:00          41     10        4  2018         0
# ...                               ...    ...      ...   ...       ...
# 2023-02-10 18:52:00+00:00           6      2        1  2023         0
# 2023-02-10 19:04:00+00:00           6      2        1  2023         0
# 2023-02-10 19:16:00+00:00           6      2        1  2023         0
# 2023-02-10 19:28:00+00:00           6      2        1  2023         0
# 2023-02-10 19:40:00+00:00           6      2        1  2023         0
#
# [166051 rows x 21 columns]

# %% [markdown]
# ## Numeriser au besoin toutes les colonnes qui ne sont pas numeriques

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166051 entries, 2018-10-10 22:28:00+00:00 to 2023-02-10 19:40:00+00:00
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   distx          166051 non-null  float64
#  1   disty          166051 non-null  float64
#  2   T_Amb_h        166051 non-null  float64
#  3   T_Fc_h         166051 non-null  float64
#  4   Vbat           166051 non-null  float64
#  5   minuteofhour   166051 non-null  int32
#  6   minuteofday    166051 non-null  int32
#  7   minuteofmonth  166051 non-null  int32
#  8   minuteofyear   166051 non-null  int32
#  9   hourofday      166051 non-null  int32
#  10  hourofmonth    166051 non-null  int32
#  11  hourofyear     166051 non-null  int32
#  12  dayofweek      166051 non-null  int32
#  13  dayofmonth     166051 non-null  int32
#  14  dayofyear      166051 non-null  int32
#  15  weekofmonth    166051 non-null  int32
#  16  weekofyear     166051 non-null  UInt32
#  17  month          166051 non-null  int32
#  18  quarter        166051 non-null  int32
#  19  year           166051 non-null  int32
#  20  holidays       166051 non-null  int64
# dtypes: UInt32(1), float64(5), int32(14), int64(1)
# memory usage: 22.6 MB

# %% [markdown]
# ## Test de stationnarité

# %% [markdown]
# la p valeur est la probabilite que l'ghypothese nulle soit vraie. la p valeur doit etre inferieure au pourcentage et la statisque inferieure a la valeur critique

# %%
def check_stationarity(series):
    result = adfuller(series.dropna())
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    for key, value in result[4].items():
        print('Critical Values:')
        print(f'   {key}, {value}')
        
#test de stationnarite
print("Serie distx:")
check_stationarity(df['distx'])
print("\nSerie disty:")
check_stationarity(df['disty'])
# Out:
# Serie distx:
# ADF Statistic: -12.357147388185606
# p-value: 5.652777414736498e-23
# Critical Values:
#    1%, -3.430389400391267
# Critical Values:
#    5%, -2.861557414431936
# Critical Values:
#    10%, -2.5667792690794555
#
# Serie disty:
# ADF Statistic: -9.980877414822045
# p-value: 2.116414516407072e-17
# Critical Values:
#    1%, -3.430389400391267
# Critical Values:
#    5%, -2.861557414431936
# Critical Values:
#    10%, -2.5667792690794555

# %% [markdown]
# La fonction check_stationarity que vous avez écrite utilise le test de Dickey-Fuller augmenté (ADF) pour vérifier la stationnarité d'une série temporelle. Voici comment interpréter les résultats du test de stationnarité :
#
# Interprétation des Résultats du Test ADF
# ADF Statistic : C'est la statistique de test calculée. Elle est comparée aux valeurs critiques pour déterminer si la série est stationnaire.
# p-value : La valeur p associée au test. Elle indique la probabilité de rejeter l'hypothèse nulle (que la série n'est pas stationnaire) à un certain niveau de confiance.
# Critical Values : Les valeurs critiques pour différents niveaux de signification (1%, 5%, 10%). Elles sont utilisées pour comparer la statistique de test et décider si l'hypothèse nulle peut être rejetée.
# Pas-à-Pas pour Interpréter les Résultats
# Étape 1 : Hypothèses
# Hypothèse nulle (H0) : La série temporelle n'est pas stationnaire.
# Hypothèse alternative (H1) : La série temporelle est stationnaire.
# Étape 2 : Comparer l'ADF Statistic aux Critical Values
# Si l'ADF Statistic est plus petite que les valeurs critiques (c'est-à-dire, plus négative), vous pouvez rejeter l'hypothèse nulle en faveur de l'hypothèse alternative, indiquant que la série est stationnaire.
# Étape 3 : Examiner la p-value
# Si la p-value est inférieure à un certain seuil de signification (par exemple 0.05), vous pouvez rejeter l'hypothèse nulle. Une p-value basse (inférieure à 0.05) indique que la série est probablement stationnaire.
# Exemple d'Interprétation
# Supposons les résultats suivants pour df['distx'] :
# ADF Statistic: -3.500
# p-value: 0.015
# Critical Values:
# 1%: -3.430
# 5%: -2.860
# 10%: -2.570
# Interprétation pour distx :
# L'ADF Statistic (-3.500) est plus petite que les valeurs critiques à 1% (-3.430), 5% (-2.860) et 10% (-2.570).
# La p-value (0.015) est inférieure à 0.05.
# Conclusion : Vous pouvez rejeter l'hypothèse nulle à tous les niveaux de signification (1%, 5%, 10%). Cela signifie que la série distx est stationnaire.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166051 entries, 2018-10-10 22:28:00+00:00 to 2023-02-10 19:40:00+00:00
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   distx          166051 non-null  float64
#  1   disty          166051 non-null  float64
#  2   T_Amb_h        166051 non-null  float64
#  3   T_Fc_h         166051 non-null  float64
#  4   Vbat           166051 non-null  float64
#  5   minuteofhour   166051 non-null  int32
#  6   minuteofday    166051 non-null  int32
#  7   minuteofmonth  166051 non-null  int32
#  8   minuteofyear   166051 non-null  int32
#  9   hourofday      166051 non-null  int32
#  10  hourofmonth    166051 non-null  int32
#  11  hourofyear     166051 non-null  int32
#  12  dayofweek      166051 non-null  int32
#  13  dayofmonth     166051 non-null  int32
#  14  dayofyear      166051 non-null  int32
#  15  weekofmonth    166051 non-null  int32
#  16  weekofyear     166051 non-null  UInt32
#  17  month          166051 non-null  int32
#  18  quarter        166051 non-null  int32
#  19  year           166051 non-null  int32
#  20  holidays       166051 non-null  int64
# dtypes: UInt32(1), float64(5), int32(14), int64(1)
# memory usage: 22.6 MB

# %% [markdown]
# ## Enregistrement des donnees traitees dans un fichier csv

# %%
df.to_csv('xgboost_datas_traitees', index=True)
#df = pd.read_csv('datas_traitees', index_col='date', parse_dates=True)

# %% [markdown]
# ## Separation des datas en train et test

# %%
# Calculer l'indice de division
split_index = int(len(df) * 0.8)

train = df.iloc[:split_index]
test = df.iloc[split_index:]

target_colonne = ["distx", "disty"]

fig, ax = plt.subplots(figsize=(12,5))
train[target_colonne].plot(ax=ax, label="Training Set")
test[target_colonne].plot(ax=ax, label="Test Set")
ax.axvline(pd.to_datetime(df.index[split_index]), color="black", ls="--")
ax.legend(["Training Set","Test Set"])
plt.show()

# %% [markdown]
# ## Feature Correlation

# %%
df.columns
# Out:
# Index(['distx', 'disty', 'T_Amb_h', 'T_Fc_h', 'Vbat', 'minuteofhour',
#        'minuteofday', 'minuteofmonth', 'minuteofyear', 'hourofday',
#        'hourofmonth', 'hourofyear', 'dayofweek', 'dayofmonth', 'dayofyear',
#        'weekofmonth', 'weekofyear', 'month', 'quarter', 'year', 'holidays'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166051 entries, 2018-10-10 22:28:00+00:00 to 2023-02-10 19:40:00+00:00
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   distx          166051 non-null  float64
#  1   disty          166051 non-null  float64
#  2   T_Amb_h        166051 non-null  float64
#  3   T_Fc_h         166051 non-null  float64
#  4   Vbat           166051 non-null  float64
#  5   minuteofhour   166051 non-null  int32
#  6   minuteofday    166051 non-null  int32
#  7   minuteofmonth  166051 non-null  int32
#  8   minuteofyear   166051 non-null  int32
#  9   hourofday      166051 non-null  int32
#  10  hourofmonth    166051 non-null  int32
#  11  hourofyear     166051 non-null  int32
#  12  dayofweek      166051 non-null  int32
#  13  dayofmonth     166051 non-null  int32
#  14  dayofyear      166051 non-null  int32
#  15  weekofmonth    166051 non-null  int32
#  16  weekofyear     166051 non-null  UInt32
#  17  month          166051 non-null  int32
#  18  quarter        166051 non-null  int32
#  19  year           166051 non-null  int32
#  20  holidays       166051 non-null  int64
# dtypes: UInt32(1), float64(5), int32(14), int64(1)
# memory usage: 22.6 MB

# %%
# df.corr(method='spearman')
correlation_matrix = df.corr(method='pearson')

for target_column in target_colonne:
    # Trier les valeurs absolues des corrélations par rapport à la colonne cible par ordre décroissant
    sorted_correlations_abs = correlation_matrix[target_column].abs().sort_values(ascending=False)
    
    # Afficher les corrélations absolues par ordre décroissant avec la colonne cible
    print(f"\nAbsolute correlations with '{target_column}' (Pearson method):\n")
    print(sorted_correlations_abs)
    correlation_matrix
# Out:
# Absolute correlations with 'distx' (Pearson method):
#
# distx            1.000000
# T_Fc_h           0.874596
# T_Amb_h          0.855282
# disty            0.836283
# Vbat             0.275542
# hourofday        0.127699
# minuteofday      0.127638
# quarter          0.099586
# month            0.093810
# minuteofyear     0.093413
# hourofyear       0.093413
# dayofyear        0.093072
# weekofyear       0.085161
# minuteofmonth    0.031414
# hourofmonth      0.031413
# weekofmonth      0.029784
# dayofmonth       0.027104
# holidays         0.025940
# year             0.022967
# dayofweek        0.001883
# minuteofhour     0.001401
# Name: distx, dtype: float64
#
# Absolute correlations with 'disty' (Pearson method):
#
# disty            1.000000
# distx            0.836283
# T_Fc_h           0.712410
# T_Amb_h          0.711904
# year             0.516485
# Vbat             0.274842
# quarter          0.186426
# month            0.179483
# minuteofyear     0.179458
# hourofyear       0.179458
# dayofyear        0.179187
# weekofyear       0.170479
# hourofday        0.100096
# minuteofday      0.100054
# minuteofmonth    0.032754
# hourofmonth      0.032753
# weekofmonth      0.030218
# dayofmonth       0.029380
# holidays         0.019665
# dayofweek        0.002934
# minuteofhour     0.001235
# Name: disty, dtype: float64

# %%
# df.corr(method='spearman')
correlation_matrix = df.corr(method='spearman')

for target_column in target_colonne:
    # Trier les valeurs absolues des corrélations par rapport à la colonne cible par ordre décroissant
    sorted_correlations_abs = correlation_matrix[target_column].abs().sort_values(ascending=False)
    
    # Afficher les corrélations absolues par ordre décroissant avec la colonne cible
    print(f"\nAbsolute correlations with '{target_column}' (spearman method):\n")
    print(sorted_correlations_abs)
    correlation_matrix
# Out:
# Absolute correlations with 'distx' (spearman method):
#
# distx            1.000000
# T_Fc_h           0.874262
# T_Amb_h          0.854585
# disty            0.842111
# Vbat             0.345158
# hourofday        0.119345
# minuteofday      0.119216
# quarter          0.106800
# month            0.091863
# hourofyear       0.091517
# minuteofyear     0.091517
# dayofyear        0.091132
# weekofyear       0.082901
# hourofmonth      0.029275
# minuteofmonth    0.029274
# weekofmonth      0.028065
# holidays         0.027462
# year             0.026346
# dayofmonth       0.025422
# minuteofhour     0.001206
# dayofweek        0.000005
# Name: distx, dtype: float64
#
# Absolute correlations with 'disty' (spearman method):
#
# disty            1.000000
# distx            0.842111
# T_Fc_h           0.710284
# T_Amb_h          0.709259
# year             0.504690
# Vbat             0.367771
# quarter          0.184046
# month            0.169432
# hourofyear       0.169321
# minuteofyear     0.169321
# dayofyear        0.169012
# weekofyear       0.160004
# hourofday        0.098440
# minuteofday      0.098346
# hourofmonth      0.030934
# minuteofmonth    0.030934
# weekofmonth      0.028943
# dayofmonth       0.027760
# holidays         0.016184
# dayofweek        0.002283
# minuteofhour     0.001158
# Name: disty, dtype: float64

# %% [markdown]
# ### Interprétation Globale des Résultats
# SSR based F test : Ce test utilise la somme des résidus carrés (SSR) pour mesurer la proportion de la variance expliquée par les lags de la série temporelle candidate. La statistique F élevée et les p-values extrêmement faibles (0.0000) pour les lags de 1 et 2 indiquent que les lags de `feature` expliquent de manière significative la variation de `target`.
# SSR based chi2 test : Ce test transforme la statistique F en une distribution chi-carré pour évaluer l'ajustement du modèle. Les p-values de 0.0000 pour les deux lags montrent que les lags de `feature` ont une influence significative sur `target`.
# Likelihood ratio test : Ce test compare la vraisemblance des modèles avec et sans les lags de la série candidate. Les p-values de 0.0000 indiquent que les lags de `feature` ajoutent une valeur prédictive significative au modèle de `target`.
# Parameter F test : Ce test est similaire au SSR based F test et vérifie les paramètres du modèle. Les p-values de 0.0000 confirment encore une fois la relation significative entre les lags de `feature` et `target`.
#
# ### Conclusion
# Les résultats des tests de causalité de Granger montrent une relation de causalité significative entre `feature` et `target`. Les valeurs passées de `feature` sont utiles pour prédire les valeurs futures de `target`, comme indiqué par les p-values très faibles pour tous les tests et pour les lags de 1 et 2 périodes. Cela suggère que `feature` Granger-cause `target`, ce qui est essentiel pour la modélisation et la prévision des séries temporelles dans ce contexte. Plus p est faible (<0.05) plus la variable doit etre utilisee pour la prediction.

# %%
max_lag = 1

list_colonne = df.columns

for target_column in target_colonne:
    print(f"Granger Causality Test for '{target_column}':")
    for i in list_colonne:
        if i not in target_colonne:
            print(i)
            grangercausalitytests(train[[i, target_column]], maxlag=max_lag)
            print("---------------------------------------------------------------------------------")
    print("\n====================================================================================")
# Out:
# Granger Causality Test for 'distx':
# T_Amb_h
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=819.3542, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=819.3727, p=0.0000  , df=1
# likelihood ratio test: chi2=816.8560, p=0.0000  , df=1
# parameter F test:         F=819.3542, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# T_Fc_h
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1183.4127, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=1183.4394, p=0.0000  , df=1
# likelihood ratio test: chi2=1178.1990, p=0.0000  , df=1
# parameter F test:         F=1183.4127, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# Vbat
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=605.3358, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=605.3495, p=0.0000  , df=1
# likelihood ratio test: chi2=603.9744, p=0.0000  , df=1
# parameter F test:         F=605.3358, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofhour
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6162  , p=0.4325  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.6162  , p=0.4325  , df=1
# likelihood ratio test: chi2=0.6162  , p=0.4325  , df=1
# parameter F test:         F=0.6162  , p=0.4325  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofday
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=386.2781, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=386.2868, p=0.0000  , df=1
# likelihood ratio test: chi2=385.7263, p=0.0000  , df=1
# parameter F test:         F=386.2781, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.1806  , p=0.0409  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=4.1807  , p=0.0409  , df=1
# likelihood ratio test: chi2=4.1806  , p=0.0409  , df=1
# parameter F test:         F=4.1806  , p=0.0409  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.0827  , p=0.0026  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=9.0829  , p=0.0026  , df=1
# likelihood ratio test: chi2=9.0826  , p=0.0026  , df=1
# parameter F test:         F=9.0827  , p=0.0026  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# hourofday
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=388.2290, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=388.2378, p=0.0000  , df=1
# likelihood ratio test: chi2=387.6715, p=0.0000  , df=1
# parameter F test:         F=388.2290, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# hourofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.1710  , p=0.0411  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=4.1710  , p=0.0411  , df=1
# likelihood ratio test: chi2=4.1710  , p=0.0411  , df=1
# parameter F test:         F=4.1710  , p=0.0411  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# hourofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.0784  , p=0.0026  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=9.0786  , p=0.0026  , df=1
# likelihood ratio test: chi2=9.0783  , p=0.0026  , df=1
# parameter F test:         F=9.0784  , p=0.0026  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# dayofweek
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3408  , p=0.5594  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.3408  , p=0.5594  , df=1
# likelihood ratio test: chi2=0.3408  , p=0.5594  , df=1
# parameter F test:         F=0.3408  , p=0.5594  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# dayofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0073  , p=0.9318  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.0073  , p=0.9318  , df=1
# likelihood ratio test: chi2=0.0073  , p=0.9318  , df=1
# parameter F test:         F=0.0073  , p=0.9318  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# dayofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.0888  , p=0.0136  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=6.0890  , p=0.0136  , df=1
# likelihood ratio test: chi2=6.0888  , p=0.0136  , df=1
# parameter F test:         F=6.0888  , p=0.0136  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# weekofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0081  , p=0.9282  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.0081  , p=0.9282  , df=1
# likelihood ratio test: chi2=0.0081  , p=0.9282  , df=1
# parameter F test:         F=0.0081  , p=0.9282  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# weekofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.7319  , p=0.0167  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=5.7320  , p=0.0167  , df=1
# likelihood ratio test: chi2=5.7319  , p=0.0167  , df=1
# parameter F test:         F=5.7319  , p=0.0167  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# month
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.9925  , p=0.0082  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=6.9927  , p=0.0082  , df=1
# likelihood ratio test: chi2=6.9925  , p=0.0082  , df=1
# parameter F test:         F=6.9925  , p=0.0082  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# quarter
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.3822  , p=0.0038  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=8.3824  , p=0.0038  , df=1
# likelihood ratio test: chi2=8.3821  , p=0.0038  , df=1
# parameter F test:         F=8.3822  , p=0.0038  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# year
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.7202  , p=0.0055  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=7.7204  , p=0.0055  , df=1
# likelihood ratio test: chi2=7.7202  , p=0.0055  , df=1
# parameter F test:         F=7.7202  , p=0.0055  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# holidays
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3741  , p=0.5408  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.3741  , p=0.5408  , df=1
# likelihood ratio test: chi2=0.3741  , p=0.5408  , df=1
# parameter F test:         F=0.3741  , p=0.5408  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
#
# ====================================================================================
# Granger Causality Test for 'disty':
# T_Amb_h
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=172.8311, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=172.8350, p=0.0000  , df=1
# likelihood ratio test: chi2=172.7226, p=0.0000  , df=1
# parameter F test:         F=172.8311, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# T_Fc_h
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=234.6483, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=234.6536, p=0.0000  , df=1
# likelihood ratio test: chi2=234.4466, p=0.0000  , df=1
# parameter F test:         F=234.6483, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# Vbat
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=400.9958, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=401.0048, p=0.0000  , df=1
# likelihood ratio test: chi2=400.4008, p=0.0000  , df=1
# parameter F test:         F=400.9958, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofhour
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2712  , p=0.6025  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.2712  , p=0.6025  , df=1
# likelihood ratio test: chi2=0.2712  , p=0.6025  , df=1
# parameter F test:         F=0.2712  , p=0.6025  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofday
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=294.7007, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=294.7074, p=0.0000  , df=1
# likelihood ratio test: chi2=294.3810, p=0.0000  , df=1
# parameter F test:         F=294.7007, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.2273  , p=0.0398  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=4.2274  , p=0.0398  , df=1
# likelihood ratio test: chi2=4.2273  , p=0.0398  , df=1
# parameter F test:         F=4.2273  , p=0.0398  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# minuteofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.1530  , p=0.0025  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=9.1532  , p=0.0025  , df=1
# likelihood ratio test: chi2=9.1529  , p=0.0025  , df=1
# parameter F test:         F=9.1530  , p=0.0025  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# hourofday
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=297.6166, p=0.0000  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=297.6233, p=0.0000  , df=1
# likelihood ratio test: chi2=297.2904, p=0.0000  , df=1
# parameter F test:         F=297.6166, p=0.0000  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# hourofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.2248  , p=0.0398  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=4.2249  , p=0.0398  , df=1
# likelihood ratio test: chi2=4.2248  , p=0.0398  , df=1
# parameter F test:         F=4.2248  , p=0.0398  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# hourofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.1513  , p=0.0025  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=9.1515  , p=0.0025  , df=1
# likelihood ratio test: chi2=9.1511  , p=0.0025  , df=1
# parameter F test:         F=9.1513  , p=0.0025  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# dayofweek
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3513  , p=0.5534  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.3513  , p=0.5534  , df=1
# likelihood ratio test: chi2=0.3513  , p=0.5534  , df=1
# parameter F test:         F=0.3513  , p=0.5534  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# dayofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0002  , p=0.9886  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.0002  , p=0.9886  , df=1
# likelihood ratio test: chi2=0.0002  , p=0.9886  , df=1
# parameter F test:         F=0.0002  , p=0.9886  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# dayofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.1850  , p=0.0129  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=6.1851  , p=0.0129  , df=1
# likelihood ratio test: chi2=6.1850  , p=0.0129  , df=1
# parameter F test:         F=6.1850  , p=0.0129  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# weekofmonth
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0309  , p=0.8604  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.0309  , p=0.8604  , df=1
# likelihood ratio test: chi2=0.0309  , p=0.8604  , df=1
# parameter F test:         F=0.0309  , p=0.8604  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# weekofyear
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.0533  , p=0.0139  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=6.0534  , p=0.0139  , df=1
# likelihood ratio test: chi2=6.0533  , p=0.0139  , df=1
# parameter F test:         F=6.0533  , p=0.0139  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# month
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.8663  , p=0.0088  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=6.8664  , p=0.0088  , df=1
# likelihood ratio test: chi2=6.8662  , p=0.0088  , df=1
# parameter F test:         F=6.8663  , p=0.0088  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# quarter
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.9429  , p=0.0048  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=7.9431  , p=0.0048  , df=1
# likelihood ratio test: chi2=7.9428  , p=0.0048  , df=1
# parameter F test:         F=7.9429  , p=0.0048  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# year
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.7721  , p=0.0031  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=8.7723  , p=0.0031  , df=1
# likelihood ratio test: chi2=8.7720  , p=0.0031  , df=1
# parameter F test:         F=8.7721  , p=0.0031  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
# holidays
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4665  , p=0.4946  , df_denom=132836, df_num=1
# ssr based chi2 test:   chi2=0.4665  , p=0.4946  , df=1
# likelihood ratio test: chi2=0.4665  , p=0.4946  , df=1
# parameter F test:         F=0.4665  , p=0.4946  , df_denom=132836, df_num=1
# ---------------------------------------------------------------------------------
#
# ====================================================================================

# %% [markdown]
# ### Maintenant a base des deux resultats precedents, on peut choisir les varialbles explicatives avec lequelles on veux faire la regression.

# %% [markdown]
# ## Predictions

# %% [markdown]
# ## DistX

# %%
train.columns
# Out:
# Index(['distx', 'disty', 'T_Amb_h', 'T_Fc_h', 'Vbat', 'minuteofhour',
#        'minuteofday', 'minuteofmonth', 'minuteofyear', 'hourofday',
#        'hourofmonth', 'hourofyear', 'dayofweek', 'dayofmonth', 'dayofyear',
#        'weekofmonth', 'weekofyear', 'month', 'quarter', 'year', 'holidays'],
#       dtype='object')

# %%
# Création des variables explicatives et de la variable cible
feature = ['T_Amb_h', 'T_Fc_h', 'Vbat','hourofday', 'hourofmonth']
target = 'distx'

# %%
x_train = train[feature]
y_train = train[target]
x_test = test[feature]
y_test = test[target]

# %% [markdown]
# ### Recherche des meilleurs parametres

# %%
import json

# Chemin du fichier JSON où vous voulez stocker/charger les paramètres optimaux
chemin_fichier_json = "xgboost_parametres_optimaux_x_xgb.json"

# Fonction pour rechercher les meilleurs paramètres pour XGBoost
def find_best_params_xgb(X_train, y_train):
    param_dist = {
        'n_estimators': [100, 200, 300, 400, 500],
        'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
        'max_depth': [3, 4, 5, 6, 7],
        'min_child_weight': [1, 3, 5, 7],
        'gamma': [0, 0.1, 0.2, 0.3, 0.4],
        'subsample': [0.6, 0.7, 0.8, 0.9],
        'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
        'reg_alpha': [0, 0.1, 0.5, 1, 2],
        'reg_lambda': [0, 0.1, 0.5, 1, 2]
    }
    
    # Randomized Search
    random_search = RandomizedSearchCV(XGBRegressor(objective='reg:squarederror'), param_distributions=param_dist, 
                                       n_iter=50, scoring='neg_mean_squared_error', cv=5, verbose=1, random_state=42, n_jobs=-1)
    random_search.fit(X_train, y_train)
    best_params_random = random_search.best_params_
    
    # Narrowed Grid Search
    param_grid = {
        'n_estimators': [best_params_random['n_estimators']-50, best_params_random['n_estimators'], best_params_random['n_estimators']+50],
        'learning_rate': [best_params_random['learning_rate']/2, best_params_random['learning_rate'], best_params_random['learning_rate']*2],
        'max_depth': [best_params_random['max_depth']-1, best_params_random['max_depth'], best_params_random['max_depth']+1],
        'min_child_weight': [best_params_random['min_child_weight']-1, best_params_random['min_child_weight'], best_params_random['min_child_weight']+1],
        'gamma': [best_params_random['gamma']/2, best_params_random['gamma'], best_params_random['gamma']*2],
        'subsample': [max(0.6, best_params_random['subsample']-0.1), best_params_random['subsample'], min(0.9, best_params_random['subsample']+0.1)],
        'colsample_bytree': [max(0.6, best_params_random['colsample_bytree']-0.1), best_params_random['colsample_bytree'], min(0.9, best_params_random['colsample_bytree']+0.1)],
        'reg_alpha': [max(0, best_params_random['reg_alpha']-0.5), best_params_random['reg_alpha'], best_params_random['reg_alpha']+0.5],
        'reg_lambda': [max(0, best_params_random['reg_lambda']-0.5), best_params_random['reg_lambda'], best_params_random['reg_lambda']+0.5]
    }
    
    grid_search = GridSearchCV(XGBRegressor(objective='reg:squarederror'), param_grid, cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_params = grid_search.best_params_
    return best_params

# Vérifier si le fichier JSON existe
if os.path.exists(chemin_fichier_json):
    # Si le fichier JSON existe, lire les paramètres optimaux depuis le fichier
    with open(chemin_fichier_json, 'r') as fichier:
        best_params_xgb = json.load(fichier)
    print("Paramètres optimaux XGBoost récupérés :", best_params_xgb)
else:
    # Si le fichier JSON n'existe pas, exécuter l'algorithme de recherche des paramètres
    # et enregistrer les paramètres optimaux dans le fichier
    best_params_xgb = find_best_params_xgb(x_train, y_train)
    with open(chemin_fichier_json, 'w') as fichier:
        json.dump(best_params_xgb, fichier)
    print("Paramètres optimaux XGBoost enregistrés :", best_params_xgb)
# Out:
# Paramètres optimaux XGBoost récupérés : {'colsample_bytree': 0.7000000000000001, 'gamma': 0.0, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 0, 'n_estimators': 200, 'reg_alpha': 2.5, 'reg_lambda': 0.6, 'subsample': 0.8}

# %% [markdown]
# ### Creation du model

# %%
# Entraînement du modèle XGBoost avec les meilleurs paramètres
model_xgb = XGBRegressor(objective='reg:squarederror', **best_params_xgb)

# %% [markdown]
# ### Entrainement du model

# %%
# Enregistrer le temps de début
start_time = time.time()

model_xgb.fit(x_train, y_train)

# Enregistrer le temps de fin
end_time = time.time()

# %% [markdown]
# ### Phase de prediction

# %%
y_pred_xgb = model_xgb.predict(x_test)

# %% [markdown]
# ### Calcul et affichage de l'erreur

# %%
mse_xgb = mean_squared_error(y_test, y_pred_xgb)

# Affichage des résultats
print("MSE XGBoost:", mse_xgb)

# RSME XGBoost
rmse_xgb = np.sqrt(mse_xgb)
print("RSME XGBoost:", rmse_xgb)

#accuracy
accuracy = model_xgb.score(x_test, y_test)
print("Accuracy XGBoost:", accuracy)

# Calculer la durée d'exécution en secondes
execution_time = end_time - start_time
print("Temps d'exécution :", execution_time, "secondes")
# Out:
# MSE XGBoost: 36.8190143726328
# RSME XGBoost: 6.067867366104239
# Accuracy XGBoost: 0.791916416019103
# Temps d'exécution : 0.8219921588897705 secondes

# %% [markdown]
# ### Visualisation des resultats

# %%
test["prediction_x"] = y_pred_xgb
test[[target,"prediction_x"]]
# Out:
# C:\Users\DM8196\AppData\Local\Temp\ipykernel_22520\2915797878.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["prediction_x"] = y_pred_xgb
#                             distx  prediction_x
# date
# 2022-03-20 01:28:00+00:00  1507.0   1503.918335
# 2022-03-20 01:40:00+00:00  1507.0   1502.468872
# 2022-03-20 01:52:00+00:00  1507.0   1501.794067
# 2022-03-20 02:04:00+00:00  1507.0   1501.592407
# 2022-03-20 02:16:00+00:00  1507.0   1501.481812
# ...                           ...           ...
# 2023-02-10 18:52:00+00:00  1514.0   1509.389404
# 2023-02-10 19:04:00+00:00  1514.0   1509.422241
# 2023-02-10 19:16:00+00:00  1514.0   1509.603638
# 2023-02-10 19:28:00+00:00  1515.0   1509.603638
# 2023-02-10 19:40:00+00:00  1515.0   1509.940308
#
# [33211 rows x 2 columns]

# %%
# Visualisation des résultats
plt.figure(figsize=(14, 7))
target_test = test['distx']
prediction = test['prediction_x']
plt.plot(df.index[-len(y_test):], target_test, label='Vraies Valeurs', color='black')
plt.plot(df.index[-len(y_test):], prediction, label='XGBoost', color='blue')

plt.legend()
plt.title('Comparaison des modèles de prévision')
plt.xlabel('Date')
plt.ylabel('Valeur')
plt.show()

# %%
# Définir l'intervalle de dates
start_date = '2022-08-10'
end_date = '2023-02-10'

# Filtrer les données pour cet intervalle
mask = (test.index >= start_date) & (test.index <= end_date)
filtered_dates = test.index[mask]
filtered_y_test = target_test[mask]
filtered_y_pred_rf = prediction[mask]

# Visualisation des résultats pour l'intervalle de dates spécifié
plt.figure(figsize=(14, 7))
plt.plot(filtered_dates, filtered_y_test, label='Vraies Valeurs', color='black')
plt.plot(filtered_dates, filtered_y_pred_rf, label='Xgboost', color='blue')

plt.legend()
plt.title('Comparaison des modèles de prévision')
plt.xlabel('Date')
plt.ylabel('Valeur')
plt.show()

# %% [markdown]
# ## DistY

# %%
# Création des variables explicatives et de la variable cible
feature = ['T_Amb_h', 'T_Fc_h', 'Vbat','hourofday', 'hourofmonth']
target = 'disty'

x_train = train[feature]
y_train = train[target]
x_test = test[feature]
y_test = test[target]

# Chemin du fichier JSON où vous voulez stocker/charger les paramètres optimaux
chemin_fichier_json = "xgboost_parametres_optimaux_y_xgb.json"

# Fonction pour rechercher les meilleurs paramètres pour XGBoost
def find_best_params_xgb(X_train, y_train):
    param_dist = {
        'n_estimators': [100, 200, 300, 400, 500],
        'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
        'max_depth': [3, 4, 5, 6, 7],
        'min_child_weight': [1, 3, 5, 7],
        'gamma': [0, 0.1, 0.2, 0.3, 0.4],
        'subsample': [0.6, 0.7, 0.8, 0.9],
        'colsample_bytree': [0.6, 0.7, 0.8, 0.9],
        'reg_alpha': [0, 0.1, 0.5, 1, 2],
        'reg_lambda': [0, 0.1, 0.5, 1, 2]
    }
    
    # Randomized Search
    random_search = RandomizedSearchCV(XGBRegressor(objective='reg:squarederror'), param_distributions=param_dist, 
                                       n_iter=50, scoring='neg_mean_squared_error', cv=5, verbose=1, random_state=42, n_jobs=-1)
    random_search.fit(X_train, y_train)
    best_params_random = random_search.best_params_
    
    # Narrowed Grid Search
    param_grid = {
        'n_estimators': [best_params_random['n_estimators']-50, best_params_random['n_estimators'], best_params_random['n_estimators']+50],
        'learning_rate': [best_params_random['learning_rate']/2, best_params_random['learning_rate'], best_params_random['learning_rate']*2],
        'max_depth': [best_params_random['max_depth']-1, best_params_random['max_depth'], best_params_random['max_depth']+1],
        'min_child_weight': [best_params_random['min_child_weight']-1, best_params_random['min_child_weight'], best_params_random['min_child_weight']+1],
        'gamma': [best_params_random['gamma']/2, best_params_random['gamma'], best_params_random['gamma']*2],
        'subsample': [max(0.6, best_params_random['subsample']-0.1), best_params_random['subsample'], min(0.9, best_params_random['subsample']+0.1)],
        'colsample_bytree': [max(0.6, best_params_random['colsample_bytree']-0.1), best_params_random['colsample_bytree'], min(0.9, best_params_random['colsample_bytree']+0.1)],
        'reg_alpha': [max(0, best_params_random['reg_alpha']-0.5), best_params_random['reg_alpha'], best_params_random['reg_alpha']+0.5],
        'reg_lambda': [max(0, best_params_random['reg_lambda']-0.5), best_params_random['reg_lambda'], best_params_random['reg_lambda']+0.5]
    }
    
    grid_search = GridSearchCV(XGBRegressor(objective='reg:squarederror'), param_grid, cv=5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_params = grid_search.best_params_
    return best_params

# Vérifier si le fichier JSON existe
if os.path.exists(chemin_fichier_json):
    # Si le fichier JSON existe, lire les paramètres optimaux depuis le fichier
    with open(chemin_fichier_json, 'r') as fichier:
        best_params_xgb = json.load(fichier)
    print("Paramètres optimaux XGBoost récupérés :", best_params_xgb)
else:
    # Si le fichier JSON n'existe pas, exécuter l'algorithme de recherche des paramètres
    # et enregistrer les paramètres optimaux dans le fichier
    best_params_xgb = find_best_params_xgb(x_train, y_train)
    with open(chemin_fichier_json, 'w') as fichier:
        json.dump(best_params_xgb, fichier)
    print("Paramètres optimaux XGBoost enregistrés :", best_params_xgb)
    

# Entraînement du modèle XGBoost avec les meilleurs paramètres
model_xgb = XGBRegressor(objective='reg:squarederror', **best_params_xgb)

# Enregistrer le temps de début
start_time = time.time()

model_xgb.fit(x_train, y_train)

# Enregistrer le temps de fin
end_time = time.time()

y_pred_xgb = model_xgb.predict(x_test)

mse_xgb = mean_squared_error(y_test, y_pred_xgb)

# Affichage des résultats
print("MSE XGBoost:", mse_xgb)

# RSME XGBoost
rmse_xgb = np.sqrt(mse_xgb)
print("RSME XGBoost:", rmse_xgb)

#accuracy
accuracy = model_xgb.score(x_test, y_test)
print("Accuracy XGBoost:", accuracy)

# Calculer la durée d'exécution en secondes
execution_time = end_time - start_time
print("Temps d'exécution :", execution_time, "secondes")

test["prediction_y"] = y_pred_xgb
test[[target,"prediction_y"]]
# Out:
# Paramètres optimaux XGBoost récupérés : {'colsample_bytree': 0.8, 'gamma': 0.0, 'learning_rate': 0.005, 'max_depth': 4, 'min_child_weight': 0, 'n_estimators': 250, 'reg_alpha': 2.5, 'reg_lambda': 0.1, 'subsample': 0.9}
# MSE XGBoost: 3255.2925743322694
# RSME XGBoost: 57.05517131980474
# Accuracy XGBoost: 0.08917248921946308
# Temps d'exécution : 1.5053980350494385 secondes
# C:\Users\DM8196\AppData\Local\Temp\ipykernel_22520\1452261036.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["prediction_y"] = y_pred_xgb
#                             disty  prediction_y
# date
# 2022-03-20 01:28:00+00:00  3842.0   3923.378174
# 2022-03-20 01:40:00+00:00  3842.0   3928.637451
# 2022-03-20 01:52:00+00:00  3843.0   3930.463867
# 2022-03-20 02:04:00+00:00  3843.0   3933.742188
# 2022-03-20 02:16:00+00:00  3843.0   3936.449707
# ...                           ...           ...
# 2023-02-10 18:52:00+00:00  3795.0   3907.133789
# 2023-02-10 19:04:00+00:00  3794.0   3906.997559
# 2023-02-10 19:16:00+00:00  3792.0   3903.989258
# 2023-02-10 19:28:00+00:00  3791.0   3889.779541
# 2023-02-10 19:40:00+00:00  3788.0   3883.376709
#
# [33211 rows x 2 columns]

# %%
# Visualisation des résultats
plt.figure(figsize=(14, 7))
target_test = test['disty']
prediction = test['prediction_y']
plt.plot(df.index[-len(y_test):], target_test, label='Vraies Valeurs', color='black')
plt.plot(df.index[-len(y_test):], prediction, label='XGBoost', color='blue')

plt.legend()
plt.title('Comparaison des modèles de prévision')
plt.xlabel('Date')
plt.ylabel('Valeur')
plt.show()

# %%
# Définir l'intervalle de dates
start_date = '2022-10-10'
end_date = '2022-12-10'

# Filtrer les données pour cet intervalle
mask = (test.index >= start_date) & (test.index <= end_date)
filtered_dates = test.index[mask]
filtered_y_test = target_test[mask]
filtered_y_pred_rf = prediction[mask]

# Visualisation des résultats pour l'intervalle de dates spécifié
plt.figure(figsize=(14, 7))
plt.plot(filtered_dates, filtered_y_test, label='Vraies Valeurs', color='black')
plt.plot(filtered_dates, filtered_y_pred_rf, label='Xgboost', color='blue')

plt.legend()
plt.title('Comparaison des modèles de prévision')
plt.xlabel('Date')
plt.ylabel('Valeur')
plt.show()
